# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data_directory = "/Users/lavi/Documents/Consulting Work/Upgrad/MLOPs Course/mlops-upgrad/mlops-upgrad/data/raw/data/"

# %%
train = pd.read_csv(data_directory+'train_v2.csv')
user_logs = pd.read_csv(data_directory+'user_logs_v2.csv')
transactions = pd.read_csv(data_directory+'transactions_v2.csv')
members = pd.read_csv(data_directory+'members_v3.csv')

# %%
from datetime import datetime
members['registration_init_time_fixed'] = members.registration_init_time.apply(lambda x: datetime.strptime(str(int(x)), "%Y%m%d").date() if pd.notnull(x) else "NAN" )
user_logs['date_time_fixed'] = user_logs.date.apply(lambda x: datetime.strptime(str(int(x)), "%Y%m%d").date() if pd.notnull(x) else "NAN" )
transactions['transaction_date_fixed'] = transactions.transaction_date.apply(lambda x: datetime.strptime(str(int(x)), "%Y%m%d").date() if pd.notnull(x) else "NAN" )
transactions['membership_expire_date_fixed'] = transactions.membership_expire_date.apply(lambda x: datetime.strptime(str(int(x)), "%Y%m%d").date() if pd.notnull(x) else "NAN" )

# %%
transactions['membership_expire_date_fixed'].describe()
# Out:
# count        1431009
# unique          1960
# top       2017-04-30
# freq          117210
# Name: membership_expire_date_fixed, dtype: object

# %%
user_logs[user_logs['msno']=='j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=']
# Out:
#                                                   msno  num_25  num_50  \
# 14216     j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       1       0
# 800733    j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      10       3
# 856635    j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       2       2
# 949023    j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      10       4
# 1070913   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      11       3
# 3536864   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       1       9
# 4501075   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      11       0
# 4825944   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       3       1
# 5151359   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      16       2
# 5521536   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      23       2
# 6172605   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       2       1
# 6374647   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      24       4
# 6820343   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      13       1
# 8770666   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      13       6
# 9720763   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       3       1
# 9834133   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       6       3
# 10636290  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      17       1
# 10975533  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       3       3
# 11155389  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       9       3
# 11334392  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       4       2
# 12182057  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       1       0
# 12234595  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       7       0
# 12407398  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       1       0
# 14956339  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       8       3
# 15667341  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       3       1
# 15850760  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=       4       1
# 17495991  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      16       1
# 17909557  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=      10       3
#
#           num_75  num_985  num_100  num_unq  total_secs date_time_fixed
# 14216          0        0        4        5    1000.648      2017-03-21
# 800733         0        4       73       73   20316.590      2017-03-29
# 856635         0        2       11       17    3614.215      2017-03-24
# 949023         3        0       61       52   16720.023      2017-03-13
# 1070913        4        1      107       55   28681.604      2017-03-27
# 3536864        2        4        4       20    3051.407      2017-03-26
# 4501075        1        2      132       67   33955.135      2017-03-15
# 4825944        2        1        7       14    2505.372      2017-03-10
# 5151359        3        1       74       76   19742.076      2017-03-20
# 5521536        4        0       50       77   13943.620      2017-03-02
# 6172605        1        0       72       53   18645.273      2017-03-06
# 6374647        5        5       25       50    9378.463      2017-03-12
# 6820343        1        1       97       63   25472.791      2017-03-17
# 8770666        5        3       11       34    5028.526      2017-03-30
# 9720763        2        1       37       32    9925.139      2017-03-22
# 9834133        0        2        7       18    2708.754      2017-03-25
# 10636290       0        5       45       52   13962.092      2017-03-11
# 10975533       1        0       34       37    9270.219      2017-03-23
# 11155389       1        2       21       24    6009.229      2017-03-19
# 11334392       3        2       70       53   18988.338      2017-03-08
# 12182057       1        0       27       21    6937.358      2017-03-16
# 12234595       0        3       36       42   10111.181      2017-03-18
# 12407398       1        2        6        8    2035.770      2017-03-01
# 14956339       0        7      134       99   36101.777      2017-03-07
# 15667341       0        1       95       68   24710.265      2017-03-28
# 15850760       5        0       62       69   17110.111      2017-03-09
# 17495991       4        4      108       58   29627.910      2017-03-31
# 17909557       3        0      116       66   30189.943      2017-03-14

# %%
user_logs[user_logs['msno']=='j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4='].groupby('msno').size()[0]
# Out:
# 28

# %%
transactions[transactions['msno']=='j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=']
# Out:
#                                                 msno  payment_method_id  \
# 98247   j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=                 39
# 218927  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=                 39
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 98247                  30              149                 149              1
# 218927                 30              149                 149              1
#
#         is_cancel transaction_date_fixed membership_expire_date_fixed
# 98247           0             2017-03-31                   2017-05-26
# 218927          0             2017-02-28                   2017-04-26

# %%
transactions[transactions['msno']=='j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4='].groupby('msno').count()['payment_method_id'].values
# Out:
# array([2])

# %%
members[members['msno']=='j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=']
# Out:
#                                                  msno  city  bd  gender  \
# 1827119  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=    13  32  female
#
#          registered_via registration_init_time_fixed
# 1827119               3                   2015-11-20

# %%
train[train['msno']=='j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=']
# Out:
#                                                 msno  is_churn
# 138455  j7vWlFtYI4gVJ5YaaloFJDq/Nymfr6imtGAY/XqY7t4=         0

# %%
members.drop(['registration_init_time'],axis=1,inplace=True)
user_logs.drop(['date'],axis=1,inplace=True)
transactions.drop(['transaction_date'],axis=1,inplace=True)
transactions.drop(['membership_expire_date'],axis=1,inplace=True)

# %%
transactions['']

# %%
transactions.head()
# Out:
#                                            msno  payment_method_id  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#    is_cancel transaction_date_fixed membership_expire_date_fixed
# 0          0             2017-01-31                   2017-05-04
# 1          0             2015-08-09                   2019-04-12
# 2          0             2017-03-03                   2017-04-22
# 3          1             2017-03-29                   2017-03-31
# 4          0             2017-03-23                   2017-04-23

# %%
members_v01 = members[members['gender'].notnull()]
members_v01_sample = members_v01.sample(frac=0.009)

# %%
members_v01_sample.shape
# Out:
# (21060, 6)

# %%
members_v01_sample.head()
# Out:
#                                                  msno  city  bd  gender  \
# 3736524  aDVEJSRYymB6CnAOjyyi3VK1UlfsJtJD4w8iD6XC7VU=     5  43    male
# 5347913  erx28V/FmeHwwfUCUtZn7um4Uv7tHOh5cMi3C4875OM=     4  24  female
# 1082482  mC7HMadzNjfncsi2bkDbp2WucUnRAo8Y1h7Jv+pcbfM=     1  16    male
# 3305942  XtnoSh2nw8KQExDvjedWvm2mgUVRGG/4CfbcIuGAY20=    22  20    male
# 2655552  R8Q/VsJtO5bnFDdV7qpCUYg6Ye3CWZnAHRIK1dCtxsc=     1  28  female
#
#          registered_via registration_init_time_fixed
# 3736524               9                   2007-05-24
# 5347913               3                   2017-04-19
# 1082482               3                   2015-07-15
# 3305942               3                   2015-04-08
# 2655552               3                   2015-08-22

# %%
# %%time
transactions_subset = transactions[transactions['msno'].isin(list(members_v01_sample['msno']))]
user_logs_subset = user_logs[user_logs['msno'].isin(list(members_v01_sample['msno']))]
# Out:
# CPU times: user 5.15 s, sys: 2.93 s, total: 8.08 s
# Wall time: 15.7 s

# %%
# %%time
def get_features(data):
#     print(data['msno'])
    membership_expire_date_last = transactions_subset[transactions_subset['msno']==data['msno']]['membership_expire_date_fixed'].max()
    total_transactions = transactions_subset[transactions_subset['msno']==data['msno']].shape[0]
    total_activaity = user_logs_subset[user_logs_subset['msno']==data['msno']].shape[0]
    return membership_expire_date_last, total_transactions, total_activaity
    

members_v01_sample[['membership_expire_date_last','total_transactions','total_activity']] = members_v01_sample.apply(get_features,axis=1, result_type="expand")
# Out:
# CPU times: user 6min 1s, sys: 9.85 s, total: 6min 11s
# Wall time: 6min 31s

# %%
members_v01_sample_transform_01 = members_v01_sample[members_v01_sample['membership_expire_date_last'].notnull()]
members_v01_sample_transform_01['registration_init_time_fixed'] = pd.to_datetime(members_v01_sample_transform_01['registration_init_time_fixed'])
members_v01_sample_transform_01['membership_expire_date_last'] = pd.to_datetime(members_v01_sample_transform_01['membership_expire_date_last'])
members_v01_sample_transform_01['time_on_platform_months'] = members_v01_sample_transform_01['membership_expire_date_last'].dt.to_period('M').astype(int)-members_v01_sample_transform_01['registration_init_time_fixed'].dt.to_period('M').astype(int)
members_v01_sample_transform_01.drop(['registration_init_time_fixed','membership_expire_date_last'], axis=1, inplace=True)
# Out:
# /var/folders/r9/_r7pks2s7432hfn6b9n1lpjc0000gn/T/ipykernel_14196/1655119439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   members_v01_sample_transform_01['registration_init_time_fixed'] = pd.to_datetime(members_v01_sample_transform_01['registration_init_time_fixed'])
# /var/folders/r9/_r7pks2s7432hfn6b9n1lpjc0000gn/T/ipykernel_14196/1655119439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   members_v01_sample_transform_01['membership_expire_date_last'] = pd.to_datetime(members_v01_sample_transform_01['membership_expire_date_last'])
# /var/folders/r9/_r7pks2s7432hfn6b9n1lpjc0000gn/T/ipykernel_14196/1655119439.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   members_v01_sample_transform_01['time_on_platform_months'] = members_v01_sample_transform_01['membership_expire_date_last'].dt.to_period('M').astype(int)-members_v01_sample_transform_01['registration_init_time_fixed'].dt.to_period('M').astype(int)
# /var/folders/r9/_r7pks2s7432hfn6b9n1lpjc0000gn/T/ipykernel_14196/1655119439.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   members_v01_sample_transform_01.drop(['registration_init_time_fixed','membership_expire_date_last'], axis=1, inplace=True)

# %%
members_v01_sample_transform_01.head()
# Out:
#                                                  msno  city  bd  gender  \
# 3305942  XtnoSh2nw8KQExDvjedWvm2mgUVRGG/4CfbcIuGAY20=    22  20    male
# 5932093  aQVBU/xPPqCLe7Rmrm+RaA+CtUw/mh11BC64ywPU/4s=    13  39  female
# 799987   qm8Y9UZlujM4gwXk0BTCePunrxgxqErMXl/n5neevpk=     4  36  female
# 2054609  WoPj+C4fN+bSeYWORLlScDdB8F71BcyvBWHW+hZIE0s=     6  27  female
# 5211935  X6jT/KVJ2SSMeCQIm3JmWxm0SdR3c6jalh9wflF8WS4=     6  24    male
#
#          registered_via  total_transactions  total_activity  \
# 3305942               3                 1.0            14.0
# 5932093               9                 1.0             3.0
# 799987                9                 1.0            24.0
# 2054609               3                 1.0            26.0
# 5211935               3                 1.0            28.0
#
#          time_on_platform_months
# 3305942                       27
# 5932093                      137
# 799987                       134
# 2054609                       37
# 5211935                       34

# %%
members_v01_sample_transform_01.shape
# Out:
# (4853, 8)

# %%
# Joins  -> train  -> user_logs -> transactions
members_v01_sample_join01 = members_v01_sample_transform_01.merge(train,on='msno')
user_logs_groupby_subset = user_logs[user_logs['msno'].isin(list(members_v01_sample_join01['msno']))].groupby(by='msno').mean()
members_v01_sample_join02 = members_v01_sample_join01.merge(user_logs_groupby_subset,on='msno')
transactions_groupby_subset = transactions[transactions['msno'].isin(list(members_v01_sample_join01['msno']))].groupby(by='msno').mean()
members_v01_sample_joinfinal = members_v01_sample_join02.merge(transactions_groupby_subset,on='msno')

# %%
members_v01_sample_joinfinal.head()
# Out:
#                                            msno  city  bd  gender  \
# 0  aQVBU/xPPqCLe7Rmrm+RaA+CtUw/mh11BC64ywPU/4s=    13  39  female
# 1  qm8Y9UZlujM4gwXk0BTCePunrxgxqErMXl/n5neevpk=     4  36  female
# 2  WoPj+C4fN+bSeYWORLlScDdB8F71BcyvBWHW+hZIE0s=     6  27  female
# 3  X6jT/KVJ2SSMeCQIm3JmWxm0SdR3c6jalh9wflF8WS4=     6  24    male
# 4  tF+18ft13i1F+4+6V43naK8LjlDdShBhgaP+r7SZ59Q=    13  38  female
#
#    registered_via  total_transactions  total_activity  \
# 0               9                 1.0             3.0
# 1               9                 1.0            24.0
# 2               3                 1.0            26.0
# 3               3                 1.0            28.0
# 4               9                 2.0            22.0
#
#    time_on_platform_months  is_churn     num_25    num_50    num_75   num_985  \
# 0                      137         0   1.333333  0.666667  0.000000  1.666667
# 1                      134         0   2.125000  0.666667  0.375000  0.416667
# 2                       37         0   9.961538  2.307692  2.153846  1.461538
# 3                       34         1  14.107143  3.357143  2.178571  1.500000
# 4                       21         0   2.181818  0.909091  0.590909  0.409091
#
#      num_100    num_unq    total_secs  payment_method_id  payment_plan_days  \
# 0  46.666667  35.000000   7390.130333               33.0               30.0
# 1  15.750000  18.250000   4061.292333               37.0               30.0
# 2  79.576923  47.038462  19032.808308               40.0               30.0
# 3  28.214286  44.785714   8085.698250               32.0              195.0
# 4  13.545455  14.727273   3346.993091               39.0               30.0
#
#    plan_list_price  actual_amount_paid  is_auto_renew  is_cancel
# 0            149.0               149.0            1.0        0.0
# 1            149.0               149.0            1.0        0.0
# 2            149.0               149.0            1.0        0.0
# 3            894.0               894.0            0.0        0.0
# 4            149.0               149.0            1.0        0.0

# %%
members_v01_sample_joinfinal.shape
# Out:
# (3058, 22)

# %%
members_v01_sample_joinfinal['is_churn'].hist()
# Out:
# <AxesSubplot:>

# %%
members_v01_sample_joinfinal.to_csv("/Users/lavi/Documents/Consulting Work/Upgrad/MLOPs Course/mlops-upgrad/mlops-upgrad/data/raw/data/members_v01_sample_joinfinal_afterfeatures.csv")
